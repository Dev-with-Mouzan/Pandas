# %% [markdown]
# # Some Basic operation on a single colums

# %%
import pandas as pd

# %%
df=pd.read_csv("Titanic-Dataset.csv")

# %%
df=df["Age"]

# %%
df
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df=df.dropna()

# %%
df
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %%
df.count()
# Out:
# np.int64(714)

# %%
df.mean().round(2)
# Out:
# np.float64(29.7)

# %%
df.max()
# Out:
# np.float64(80.0)

# %%
df.min()
# Out:
# np.float64(0.42)

# %%
df.std()
# Out:
# np.float64(14.526497332334042)
